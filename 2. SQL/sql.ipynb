# %% [markdown]
# ### 1.What will be the result of the query below?
#
# SELECT * FROM runners WHERE id NOT IN (SELECT winner_id FROM races)
#
# Explain your answer and also provide an alternative version of this query that will avoid the issue that it exposes.

# %%
 id  name       
 4   Bobby Lou  
 5   Lisa Romero

# %% [markdown]
# ### 2.Write a query to fetch values in table test_a that are and not in test_b without using the NOT keyword.

# %% [markdown]
# SELECT a.id
# FROM test_a a
# LEFT JOIN test_b b ON a.id = b.id
# WHERE b.id IS NULL;

# %% [markdown]
# ### 3.Write a query to to get the list of users who took the a training lesson more than once in the same day, grouped by user and training lesson, each ordered from the most recent lesson date to oldest date.

# %%
SELECT user_id, lesson_id, lesson_date
FROM lessons
GROUP BY user_id, lesson_id, lesson_date
HAVING COUNT(*) > 1
ORDER BY lesson_date DESC;

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# SELECT Manager_Id, Emp_name AS Manager, AVG(Salary) AS Average_Salary_Under_Manager
# FROM Employees
# WHERE Manager_Id IS NOT NULL
# GROUP BY Manager_Id, Emp_name;
